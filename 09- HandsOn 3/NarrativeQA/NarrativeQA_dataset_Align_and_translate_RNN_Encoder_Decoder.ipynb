# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank-Holla/TSAI-END-Program/blob/main/09-%20HandsOn%203/NarrativeQA/NarrativeQA_dataset_Align_and_translate_RNN_Encoder_Decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The NarrativeQA Reading Comprehension Challenge - RNN Seq2Seq Encoder Decoder solution with Translation by Jointly Learning to Align and Translate
#
# The model implemented avoids compression at context vector by allowing the decoder to look at the entire source sentence (via its hidden states) at each decoding step. This is done by using Attention.
#
# Attention works by first, calculating an attention vector, $a$, that is the length of the source sentence. The attention vector has the property that each element is between 0 and 1, and the entire vector sums to 1. We then calculate a weighted sum of our source sentence hidden states, $H$, to get a weighted source vector, $w$.
#
# $$w = \sum_{i}a_ih_i$$
#
# We calculate a new weighted source vector every time-step when decoding, using it as input to our decoder RNN as well as the linear layer to make a prediction.
#
# #### Files
# * documents.csv - contains document_id, set, kind, story_url, story_file_size, wiki_url, wiki_title, story_word_count, story_start, story_end. The word count is approximate after some basic cleanup and tokenization.
#
# * third_party/wikipedia/summaries.csv - contains document_id, set, summary, summary_tokenized. The summaries are from Wikipedia.
#
# * qaps.csv - contains document_id, set, question, answer1, answer2, question_tokenized, answer1_tokenized, answer2_tokenized.
# download_stories.sh - script to download the stories.
#
# * compare.sh - compare downloaded story's file size to the document size we had. (At the time of publication, all stories have <3.5% file difference (except one), likely due to punctuation encoding.)
#
# Learnings:
#
# 1. Encoder uses bidirectional GRU to encode the context vector. Bidirection GRUs create 2 context vector, one for each direction. Decoder block requires single context vector. This is created by concatenating the two context vectors together, passing them through a linear layer, g, and applying the tanh  activation function.
#
# 2. Attention vector is calculated from previous hidden state of the decoder,  st−1 , and all of the stacked forward and backward hidden states from the encoder. Attention vector calculates how well each encoder hidden state matches the previous decoder hidden state.
#
# 3. Decoder uses the weighted attention vector along with previous decoder hidden state to calculate decoder hidden state. Attention vector is also used along with decoder hidden state to predict the next word.
#
# 4. Test Loss observed is 5.265 with perplexity score of 193.382.

# %%
# !git clone https://github.com/deepmind/narrativeqa.git
# Out:
# fatal: destination path 'narrativeqa' already exists and is not an empty directory.

# %% [markdown]
# ### Import all necessary packages

# %%
# Packages
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchtext import data
from torchtext.data import Field, BucketIterator

import spacy
import numpy as np

import random
import math
import time

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# ### Load dataset
#
# Load dataset and split into train, valid and test. We are picking question and answer1 columns to predict the seq2seq translations.

# %%
df_qaps = pd.read_csv('/content/narrativeqa/qaps.csv')
print(df_qaps.shape)
print("Columns of qaps: ",df_qaps.columns)
df_qaps.head()
# Out:
# (46765, 8)
# Columns of qaps:  Index(['document_id', 'set', 'question', 'answer1', 'answer2',
#        'question_tokenized', 'answer1_tokenized', 'answer2_tokenized'],
#       dtype='object')
#                                 document_id  ...                                  answer2_tokenized
# 0  0025577043f5090cd603c6aea60f26e236195594  ...  A loner and outsider student with a radio stat...
# 1  0025577043f5090cd603c6aea60f26e236195594  ...                                  Phoenix , Arizona
# 2  0025577043f5090cd603c6aea60f26e236195594  ...  Because he has a thing to say about what is ha...
# 3  0025577043f5090cd603c6aea60f26e236195594  ...                                          Malcolm .
# 4  0025577043f5090cd603c6aea60f26e236195594  ...                                   Her award medals
#
# [5 rows x 8 columns]

# %%
df_qaps.groupby('set').agg('count')
# Out:
#        document_id  question  ...  answer1_tokenized  answer2_tokenized
# set                           ...
# test         10557     10557  ...              10557              10557
# train        32747     32747  ...              32747              32747
# valid         3461      3461  ...               3461               3461
#
# [3 rows x 7 columns]

# %%
# Creating dataframe with only questions and answer1 columns.
# This df is going to be split into train, test and valid.
df_qaps_2columns = df_qaps[['question', 'answer1']]
df_qaps_2columns.head()
# Out:
#                                       question                                            answer1
# 0                          Who is Mark Hunter?            He is a high school student in Phoenix.
# 1    Where does this radio station take place?        It takes place in Mark's parents basement.
# 2  Why do more students tune into Mark's show?  Mark talks about what goes on at school and in...
# 3                         Who commits suicide?                                           Malcolm.
# 4      What does Paige jam into her microwave?                She jams her medals and accolades.

# %% [markdown]
# ### Download and load spacy models
#
# This is going to be used for tokenization.

# %%
# Download and load spacy models for EN language. To be used for tokenization.
# %%bash
python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.6/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (51.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
spacy_en = spacy.load('en')

# %%
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
tokenize_en("Spacy model for EN is loaded up.")
# Out:
# ['Spacy', 'model', 'for', 'EN', 'is', 'loaded', 'up', '.']

# %% [markdown]
# ### Prepare FIELDS
#
# Defines a datatype together with instructions for converting to Tensor. holds a Vocab object that defines the set of possible values
#     for elements of the field and their corresponding numerical representations.
#
# QUESTIONS - Field containing the questions for training.
# ANSWERS - Field for prediction.

# %%
QUESTIONS = Field(tokenize=tokenize_en, init_token='<sos>', eos_token='<eos>', lower=True)
ANSWERS = Field(tokenize = tokenize_en, init_token='<sos>', eos_token='<eos>', lower=True)

# %%
print(type(QUESTIONS))
QUESTIONS.__dict__
# Out:
# <class 'torchtext.data.field.Field'>
# {'batch_first': False,
#  'dtype': torch.int64,
#  'eos_token': '<eos>',
#  'fix_length': None,
#  'include_lengths': False,
#  'init_token': '<sos>',
#  'is_target': False,
#  'lower': True,
#  'pad_first': False,
#  'pad_token': '<pad>',
#  'postprocessing': None,
#  'preprocessing': None,
#  'sequential': True,
#  'stop_words': None,
#  'tokenize': <function __main__.tokenize_en>,
#  'truncate_first': False,
#  'unk_token': '<unk>',
#  'use_vocab': True}

# %% [markdown]
# Create a list of (name, field) pairs as the fields argument. The fields we pass in must be in the same order as the columns

# %%
fields = [('question', QUESTIONS), ('answer1', ANSWERS)]

# %% [markdown]
# Convert from pandas to list to torchtext

# %%
example = [data.Example.fromlist([df_qaps_2columns.question[i],df_qaps_2columns.answer1[i]], fields) for i in range(df_qaps_2columns.shape[0])]

# %%
print(type(example))
print(len(example))
print(example)
# Out:
# <class 'list'>
# 46765
# [<torchtext.data.example.Example object at 0x7f4e34bd0048>, <torchtext.data.example.Example object at 0x7f4e34bd0898>, <torchtext.data.example.Example object at 0x7f4e34bd0f60>, <torchtext.data.example.Example object at 0x7f4e34bd0eb8>, <torchtext.data.example.Example object at 0x7f4e34bd0e48>, <torchtext.data.example.Example object at 0x7f4e33db3dd8>, <torchtext.data.example.Example object at 0x7f4e34bd0e80>, <torchtext.data.example.Example object at 0x7f4e34bd0dd8>, <torchtext.data.example.Example object at 0x7f4e34bd0da0>, <torchtext.data.example.Example object at 0x7f4e34bdb320>, <torchtext.data.example.Example object at 0x7f4e33dc13c8>, <torchtext.data.example.Example object at 0x7f4e33dc10f0>, <torchtext.data.example.Example object at 0x7f4e33dc1ef0>, <torchtext.data.example.Example object at 0x7f4e33dc14a8>, <torchtext.data.example.Example object at 0x7f4e33dbf588>, <torchtext.data.example.Example object at 0x7f4e33dbf828>, <torchtext.data.example.Example object at 0x7f4e33dbfb70>, <torchtext.data.example.Example object at 0x7f4e33dbf860>, <torchtext.data.example.Example object at 0x7f4e33dbfef0>, <torchtext.data.example.Example object at 0x7f4e33dc6438>, <torchtext.data.example.Example object at 0x7f4e33dc6748>, <torchtext.data.example.Example object at 0x7f4e33dc6b38>, <torchtext.data.example.Example object at 0x7f4e33dc6e10>, <torchtext.data.example.Example object at 0x7f4e33dc6da0>, <torchtext.data.example.Example object at 0x7f4e33dc6898>, <torchtext.data.example.Example object at 0x7f4e33dc67f0>, <torchtext.data.example.Example object at 0x7f4e33dc6dd8>, <torchtext.data.example.Example object at 0x7f4e33dbfb38>, <torchtext.data.example.Example object at 0x7f4e33dbfc50>, <torchtext.data.example.Example object at 0x7f4e34bd0a90>, <torchtext.data.example.Example object at 0x7f4e33d4a550>, <torchtext.data.example.Example object at 0x7f4e33d4aac8>, <torchtext.data.example.Example object at 0x7f4e33d4ab38>, <torchtext.data.example.Example object at 0x7f4e33d4ada0>, <torchtext.data.example.Example object at 0x7f4e33d4add8>, <torchtext.data.example.Example object at 0x7f4e34bdb0b8>, <torchtext.data.example.Example object at 0x7f4e33d4d208>, <torchtext.data.example.Example object at 0x7f4e33d4dac8>, <torchtext.data.example.Example object at 0x7f4e33d4db00>, <torchtext.data.example.Example object at 0x7f4e33d4d278>, <torchtext.data.example.Example object at 0x7f4e33d4f518>, <torchtext.data.example.Example object at 0x7f4e33d4f4e0>, <torchtext.data.example.Example object at 0x7f4e33d4ff60>, <torchtext.data.example.Example object at 0x7f4e33d53b38>, <torchtext.data.example.Example object at 0x7f4e33d53be0>, <torchtext.data.example.Example object at 0x7f4e33d53c50>, <torchtext.data.example.Example object at 0x7f4e33d55710>, <torchtext.data.example.Example object at 0x7f4e33d557b8>, <torchtext.data.example.Example object at 0x7f4e33d55748>, <torchtext.data.example.Example object at 0x7f4e33d55da0>, <torchtext.data.example.Example object at 0x7f4e33d56518>, <torchtext.data.example.Example object at 0x7f4e33d565c0>, <torchtext.data.example.Example object at 0x7f4e33d56630>, <torchtext.data.example.Example object at 0x7f4e33d56940>, <torchtext.data.example.Example object at 0x7f4e33d56d68>, <torchtext.data.example.Example object at 0x7f4e33d59470>, <torchtext.data.example.Example object at 0x7f4e33d592e8>, <torchtext.data.example.Example object at 0x7f4e33d59a90>, <torchtext.data.example.Example object at 0x7f4e33d59710>, <torchtext.data.example.Example object at 0x7f4e33d59e48>, <torchtext.data.example.Example object at 0x7f4e33d5b080>, <torchtext.data.example.Example object at 0x7f4e33d5b5f8>, <torchtext.data.example.Example object at 0x7f4e33d5b7b8>, <torchtext.data.example.Example object at 0x7f4e33d5b898>, <torchtext.data.example.Example object at 0x7f4e33d5b940>, <torchtext.data.example.Example object at 0x7f4e33d5bbe0>, <torchtext.data.example.Example object at 0x7f4e33d5bcc0>, <torchtext.data.example.Example object at 0x7f ...

# %%
# Creating dataset
NarrativeQADataset = data.Dataset(example, fields)

# %%
print(vars(NarrativeQADataset.examples[0]))
print(type(NarrativeQADataset))
# Out:
# {'question': ['who', 'is', 'mark', 'hunter', '?'], 'answer1': ['he', 'is', 'a', 'high', 'school', 'student', 'in', 'phoenix', '.']}
# torchtext.data.dataset.Dataset

# %%
train_data, valid_data, test_data = NarrativeQADataset.split(split_ratio=[0.7, 0.1, 0.2], random_state=random.seed(SEED))

# %%
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
# Out:
# Number of training examples: 32735
# Number of validation examples: 9354
# Number of testing examples: 4676

# %% [markdown]
# ### Build vocabulary for SRC and TRG
#
# Vocabulary will associate each unique tokens with an index. Only tokens that appear atleast 2 times are considered. Other such words are replaced by < UNK >. Vocab object built on only training examples.

# %%
QUESTIONS.build_vocab(train_data, min_freq = 2)
ANSWERS.build_vocab(train_data, min_freq = 2)

# %%
print("Size of Source vocab: ",len(QUESTIONS.vocab))
print("Size of Target vocab: ",len(ANSWERS.vocab))
# Out:
# Size of Source vocab:  11000
# Size of Target vocab:  10651

# %%
vars(QUESTIONS)
# Out:
# {'batch_first': False,
#  'dtype': torch.int64,
#  'eos_token': '<eos>',
#  'fix_length': None,
#  'include_lengths': False,
#  'init_token': '<sos>',
#  'is_target': False,
#  'lower': True,
#  'pad_first': False,
#  'pad_token': '<pad>',
#  'postprocessing': None,
#  'preprocessing': None,
#  'sequential': True,
#  'stop_words': None,
#  'tokenize': <function __main__.tokenize_en>,
#  'truncate_first': False,
#  'unk_token': '<unk>',
#  'use_vocab': True,
#  'vocab': <torchtext.vocab.Vocab at 0x7f4e2fa7e978>}

# %%
# QUESTIONS.vocab dict has the following keys - freqs(provides word and its frequencies), itos(mapping of integer to string), 
# stoi(mapping of string to its integer) and vectors()
print(QUESTIONS.vocab.__dict__.keys())
QUESTIONS.vocab.__dict__
# Out:
# dict_keys(['freqs', 'itos', 'stoi', 'vectors'])
# {'freqs': Counter({'who': 8191,
#           'forced': 50,
#           'charles': 71,
#           'reding': 7,
#           'to': 10024,
#           'live': 314,
#           'away': 190,
#           'from': 1586,
#           'oxford': 10,
#           '?': 32749,
#           'how': 3603,
#           'did': 4014,
#           'sato': 7,
#           'and': 3294,
#           'his': 2205,
#           'gang': 54,
#           'manage': 19,
#           'lure': 7,
#           'trap': 26,
#           'charlie': 117,
#           'in': 4187,
#           'the': 19098,
#           'underground': 25,
#           'garage': 8,
#           'what': 13874,
#           'does': 9851,
#           'van': 39,
#           'martin': 101,
#           'confess': 20,
#           'kills': 187,
#           'oleg': 6,
#           'emil': 11,
#           'is': 8463,
#           'john': 339,
#           'crocker': 3,
#           'happened': 252,
#           'markell': 1,
#           'that': 1334,
#           'put': 75,
#           'justice': 22,
#           'into': 484,
#           'depression': 8,
#           'happens': 774,
#           'when': 2089,
#           'dorothea': 18,
#           'shoots': 46,
#           'nix': 8,
#           'with': 2239,
#           "d'amour": 3,
#           "'s": 5679,
#           'gun': 36,
#           'why': 3248,
#           'ca': 50,
#           "n't": 209,
#           'phillip': 39,
#           'ever': 9,
#           'have': 744,
#           'a': 2522,
#           'romantic': 28,
#           'relationship': 270,
#           'caroline': 9,
#           'was': 2974,
#           'there': 75,
#           'black': 58,
#           'powder': 3,
#           'marvins': 1,
#           "'": 370,
#           'vacation': 22,
#           'home': 259,
#           'where': 2675,
#           'mr.': 352,
#           'raven': 6,
#           'come': 177,
#           'retrieves': 5,
#           'ring': 32,
#           'lily': 20,
#           'threw': 6,
#           'pond': 4,
#           'mme': 8,
#           'walter': 66,
#           'married': 124,
#           'kind': 257,
#           'of': 5627,
#           'limitations': 1,
#           'do': 2922,
#           'aliens': 27,
#           'their': 445,
#           'technology': 6,
#           'gave': 34,
#           'romola': 7,
#           'new': 288,
#           'meaning': 8,
#           'life': 233,
#           'type': 199,
#           'love': 381,
#           'letitia': 11,
#           'seeking': 12,
#           'elicit': 2,
#           'doricourt': 6,
#           'dead': 104,
#           'nat': 7,
#           '-': 572,
#           'u': 5,
#           'ritch': 5,
#           'lying': 14,
#           'across': 28,
#           'her': 1255,
#           'father': 496,
#           'arms': 14,
#           'reversal': 1,
#           'tom': 258,
#           'interact': 2,
#           'neal': 9,
#           'truck': 20,
#           'driver': 14,
#           'refused': 7,
#           'apologize': 7,
#           'aaron': 7,
#           'hancock': 17,
#           'resemble': 17,
#           'crystal': 27,
#           'lead': 60,
#           'julian': 14,
#           'believe': 197,
#           'would': 122,
#           'change': 72,
#           'if': 130,
#           'he': 1501,
#           'killed': 356,
#           'chang': 13,
#           'family': 302,
#           'watson': 20,
#           'hear': 31,
#           'during': 281,
#           'night': 126,
#           'at': 1541,
#           'baskerville': 6,
#           'hall': 33,
#           'orgon': 16,
#           'first': 510,
#           'show': 126,
#           'sided': 1,
#           'tartuffle': 3,
#           'henry': 148,
#           'job': 315,
#           'shaw': 10,
#           'die': 459,
#           'required': 7,
#           'animate': 3,
#           'any': 19,
#           'object': 28,
#           'addition': 11,
#           'dr.': 256,
#           'pipt': 8,
#           'gaear': 4,
#           'jean': 48,
#           'but': 36,
#           'carl': 64,
#           'britomart': 5,
#           'destine': 1,
#           'found': 196,
#           'by': 725,
#           'merlin': 5,
#           'explanation': 5,
#           'princess': 73,
#           'cleve': 2,
#           'fell': 21,
#           'disease': 31,
#           'are': 1074,
#           'cockroaches': 1,
#           'spreading': 3,
#           'york': 65,
#           'raymond': 11,
#           'demand': 25,
#           'paul': 156,
#           'roxy': 10,
#           'story': 1266,
#           ',': 1707,
#           'name': 1150,
#           'british': 27,
#           'band': 30,
#           'which': 912,
#           'peggy': 17,
#           'wrote': 30,
#           'song': 42,
#           'will': 293,
#           'scarlet': 8,
#           'robin': 46,
#           'liz': 11,
#           'melts': 1,
#           'crown': 21,
#           'selena': 11,
#           'alert': 4,
#           'brewer': 10,
#           'she': 556,
#           'had': 181,
#           'been': 168,
#           '"': 621,
#           'wolf': 20,
#           'beginning': 208,
#           'sera': 14,
#           'pimp': 5,
#           'title': 83,
#           'ouisa': 6,
#           'kittredge': 4,
#           'going': 132,
#           'blackmail': 22,
#           'minor': 5,
#           'rajah': 1,
#           'genji': 16,
#           'want': 430,
#           'murasaki': 5,
#           'be': 609,
#           'like': 89,
#           'phillips': 5,
#           'career': 59,
#           'mrs.': 209,
#           'grose': 1,
#           'narrator': 132,
#           'find': 518,
#           'clearing': 2,
#           'wood': 3,
#           'beaten': 11,
#           'death': 307,
#           'ss': 2,
#           'guards': 14,
#           'little': 43,
#           'miss': 72,
#           'beverly': 14,
#           'funeral': 33,
#           'transpires': 3,
#           'delmont': 3,
#           'realizes': 16,
#           'may': 28,
#           'impregnated': 3,
#           'own': 72,
#           'daughter': 172,
#           'suitor': 11,
#           'em': 6,
#           'prefer': 8,
#           ' ': 217,
#           'jimmie': 12,
#           'maggie': 57,
#           'tommie': 1,
#           'shuddering': 1,
#           'corner': 4,
#           'jury': 6,
#           'carpenter': 4,
#           'small': 21,
#           'boy': 41,
#           'railly': 2,
#           'makes': 88,
#           'eye': 11,
#           'contact': 31,
#           'airport': 28,
#           'while': 295,
#           'cole': 39,
#           'lies': 9,
#           'dying': 49,
#           'person': 100,
#           'shooting': 22,
#           'many': 521,
#           'children': 241,
#           'jim': 106,
#           'blakeston': 4,
#           'jemima': 19,
#           'puddle': 9,
#           'duck': 9,
#           'lay': 4,
#           'eggs': 16,
#           'suggestion': 1,
#           'charming': 11,
#           'gentleman': 8,
#           'valentin': 19,
#           'collection': 14,
#           'nello': 19,
#           'patrasche': 3,
#           'paddy': 7,
#           'singleton': 11,
#           'marry': 379,
#           'concluded': 2,
#           'about': 823,
#           'jesus': 9,
#           'mordechai': 11,
#           'cheer': 5,
#           'himself': 167,
#           'up': 630,
#           'human': 41,
#           'beings': 6,
#           'creation': 6,
#           'zan': 15,
#           'all': 100,
#           'on': 1399,
#           'earth': 91,
#           'country': 160,
#           'ryan': 25,
#           'silk': 13,
#           'discover': 176,
#           'told': 64,
#           'bonney': 3,
#           'clan': 17,
#           'commit': 56,
#           'crime': 78,
#           'eve': 83,
#           'write': 47,
#           'adam': 99,
#           'wallace': 20,
#           'know': 86,
#           'murron': 6,
#           'macclannough': 1,
#           'suns': 7,
#           'inhabit': 2,
#           'planet': 75,
#           'lagash': 3,
#           'stellar': 1,
#           'system': 28,
#           'neville': 10,
#           'guilty': 24,
#           'heresy': 1,
#           'after': 1473,
#           'trial': 57,
#           'aces': 4,
#           'try': 208,
#           'kill': 408,
#           'hal': 26,
#           'decide': 188,
#           'loves': 17,
#           'end': 617,
#           'nationality': 41,
#           'wallis': 1,
#           'simpson': 1,
#           'air': 30,
#           'clog': 2,
#           'powered': 4,
#           'causing': 17,
#           'people': 260,
#           'they': 478,
#           'open': 27,
#           'trunk': 5,
#           'malibu': 5,
#           'kingdom': 24,
#           'defeats': 13,
#           'aquilonian': 3,
#           'army': 79,
#           'sarah': 76,
#           'leeson': 1,
#           'return': 204,
#           'work': 286,
#           'protagenna': 1,
#           'tower': 15,
#           'as': 769,
#           'crash': 51,
#           'witnesses': 20,
#           'happiest': 3,
#           'moment': 8,
#           'screening': 1,
#           'room': 86,
#           'rescues': 33,
#           'two': 272,
#           'cousins': 15,
#           'get': 597,
#           'trapped': 21,
#           'captured': 61,
#           'abd': 4,
#           'el': 23,
#           'kader': 4,
#           'ginger': 30,
#           'ultimately': 52,
#           'mole': 13,
#           'wife': 289,
#           'kitnapped': 1,
#           'lebowski': 8,
#           'ask': 124,
#           'dude': 11,
#           'sergius': 17,
#           'sent': 128,
#           'adjective': 1,
#           'used': 94,
#           'describe': 33,
#           'virginia': 43,
#           'st.': 34,
#           'schultz': 14,
#           'shoot': 52,
#           'candie': 4,
#           'anna': 122,
#           'boyfriend': 28,
#           'racks': 3,
#           'take': 561,
#           'trip': 72,
#           'search': 25,
#           'long': 223,
#           'arrow': 3,
#           'tried': 32,
#           'protect': 36,
#           'forest': 31,
#           'crusaders': 1,
#           'stew': 15,
#           'schuyler': 4,
#           'house': 322,
#           'reports': 7,
#           'voices': 2,
#           'affect': 12,
#           'theodore': 23,
#           'treatment': 9,
#           'holiday': 16,
#           'katie': 10,
#           'celebrating': 9,
#           'saw': 26,
#           'oscar': 31,
#           'station': 55,
#           'greenleafs': 1,
#           'cause': 67,
#           'dickie': 13,
#           'were': 388,
#           'base': 39,
#           'ripley': 42,
#           'dispose': 8,
#           'freddie': 7,
#           'mile': 2,
#           'body': 150,
#           'ash': 34,
#           'attracted': 17,
#           'roy': 35,
#           'partner': 39,
#           'helped': 48,
#           'virture;s': 1,
#           'troops': 10,
#           'manray': 5,
#           'wish': 62,
#           'become': 263,
#           'famous': 22,
#           'for': 1987,
#           'cavor': 12,
#           'brumley': 10,
#           'fall': 148,
#           'cher': 20,
#           'tai': 10,
#           'belongs': 3,
#           'emma': 52,
#           'mom': 15,
#           'bring': 64,
#           'wedding': 72,
#           'pevensie': 2,
#           'discovered': 62,
#           'narnia': 6,
#           'along': 29,
#           'mountain': 27,
#           'range': 7,
#           'fault': 9,
#           'travel': 137,
#           'dream': 61,
#           'benny': 20,
#           'linda': 60,
#           'finally': 120,
#           'escape': 200,
#           'north': 22,
#           'destination': 10,
#           'group': 176,
#           'attempting': 27,
#           'reach': 36,
#           'gray': 12,
#           'paid': 22,
#           'compaion': 1,
#           'difference': 10,
#           'between': 188,
#           'automobiles': 1,
#           'railroads': 1,
#           'set': 128,
#           'fire': 69,
#           'reason': 76,
#           'celeste': 12,
#           'jesse': 18,
#           'fought': 4,
#           'drug': 52,
#           'micheal': 3,
#           'helps': 76,
#           'design': 1,
#           'charalois': 13,
#           'negotiation': 1,
#           'qui': 8,
#           'gon': 8,
#           'jinn': 5,
#           'trying': 105,
#           'make': 229,
#           'trade': 30,
#           'federation': 7,
#           'color': 34,
#           'phoenix': 24,
#           'feather': 8,
#           'mildred': 6,
#           'yank': 8,
#           'doing': 158,
#           'ship': 208,
#           'chandler': 10,
#           'clerk': 9,
#           'president': 64,
#           'send': 99,
#           'l.a.': 7,
#           'retrieve': 17,
#           'remote': 6,
#           'sword': 15,
#           'damocles': 3,
#           'tarr': 3,
#           'admits': 9,
#           'breaking': 8,
#           'office': 38,
#           'louis': 56,
#           'phillippe': 1,
#           'woman': 152,
#           'rodgers': 5,
#           'woke': 9,
#           'ray': 70,
#           'drive': 25,
#           'over': 163,
#           'lake': 21,
#           'car': 153,
#           'whose': 215,
#           'side': 26,
#           'valeria': 4,
#           'conan': 87,
#           'montmorency': 4,
#           'dinner': 37,
#           'jewel': 3,
#           'thief': 14,
#           'threaten': 39,
#           'diamond': 18,
#           'dealer': 9,
#           'convinces': 28,
#           'sonny': 22,
#           'mother': 269,
#           'let': 31,
#           'him': 629,
#           'pursue': 27,
#           'seaton': 21,
#           'craine': 1,
#           'leave': 254,
#           'spaceship': 17,
#           'animal': 68,
#           'form': 47,
#           'mephistopheles': 6,
#           'nick': 92,
#           'gain': 43,
#           'telepathic': 4,
#           'abilities': 7,
#           'position': 76,
#           'milton': 14,
#           'waddams': 1,
#           'holds': 15,
#           'initech': 9,
#           'detects': 1,
#           'an': 401,
#           'alian': 2,
#           'force': 53,
#           'flora': 7,
#           'goes': 100,
#           'missing': 54,
#           'discovers': 45,
#           'deceit': 1,
#           'rome': 13,
#           'aisha': 5,
#           'help': 218,
#           'losers': 9,
#           'back': 252,
#           'america': 37,
#           'anakin': 9,
#           'arrive': 40,
#           'naboo': 6,
#           'grew': 5,
#           'nicname': 1,
#           'ends': 56,
#           'paying': 6,
#           'jamie': 28,
#           'care': 36,
#           'josie': 21,
#           'admit': 18,
#           'writes': 14,
#           'shark': 16,
#           'attack': 97,
#           'isabel': 39,
#           'thorne': 18,
#           'detached': 1,
#           'government': 58,
#           'alex': 57,
#           'price': 12,
#           'gabriel': 37,
#           'bank': 40,
#           'robbery': 32,
#           'stella': 11,
#           'marries': 31,
#           'feldt': 1,
#           'characters': 74,
#           'kiss': 20,
#           'elevator': 4,
#           'plume': 3,
#           'give': 281,
#           'recruits': 3,
#           'babysitter': 3,
#           'al': 11,
#           'ghazi': 7,
#           'fluery': 3,
#           'mayes': 2,
#           'follow': 35,
#           'complex': 8,
#           'profession': 233,
#           'before': 369,
#           'became': 44,
#           'professor': 33,
#           'died': 114,
#           'winter': 13,
#           'skylark': 5,
#           'land': 81,
#           'lewis': 8,
#           'clark': 8,
#           'damaged': 13,
#           'haw': 12,
#           'destroy': 51,
#           'equipment': 12,
#           'lab': 8,
#           'pablo': 13,
#           'nela': 8,
#           'beautiful': 9,
#           'suspects': 7,
#           'bill': 101,
#           'abby': 20,
#           'not': 350,
#           'related': 92,
#           'colonel': 47,
#           'fitzwilliam': 6,
#           'injure': 10,
#           'this': 314,
#           'place': 287,
#           'ben': 74,
#           'crowning': 2,
#           'jane': 71,
#           'hand': 62,
#           'has': 413,
#           'fester': 11,
#           'past': 43,
#           '25': 3,
#           'years': 132,
#           'travers': 7,
#           'inspiration': 6,
#           'writing': 31,
#           'mary': 235,
#           'poppins': 4,
#           'son': 191,
#           'palmyran': 1,
#           'king': 209,
#           'vabathus': 3,
#           'wins': 27,
#           'custody': 18,
#           'battle': 85,
#           'billy': 90,
#           'whom': 218,
#           'feed': 8,
#           'apple': 2,
#           'initially': 86,
#           'believed': 21,
#           'marvin': 14,
#           'acme': 7,
#           'false': 16,
#           'witness': 32,
#           'it': 270,
#           'so': 112,
#           'fortunate': 1,
#           'germans': 8,
#           'began': 9,
#           'shelling': 1,
#           'london': 73,
#           'august': 11,
#           'grade': 5,
#           'school': 187,
#           'brad': 23,
#           'servant': 21,
#           'jack': 215,
#           'pierre': 34,
#           'rougon': 4,
#           'pentangeli': 3,
#           'agree': 60,
#           'testify': 7,
#           'against': 123,
#           'reveals': 22,
#           'likes': 6,
#           'summer': 21,
#           'joe': 116,
#           'enter': 41,
#           'kathleen': 14,
#           'store': 47,
#           'returns': 81,
#           'russia': 10,
#           'vronsky': 7,
#           'war': 199,
#           'juliet': 16,
#           'pauline': 26,
#           'plan': 241,
#           'run': 98,
#           'one': 238,
#           'destroyed': 40,
#           'ressurected': 2,
#           'crow': 13,
#           'traveling': 36,
#           'galus': 1,
#           'ajor': 4,
#           'billings': 7,
#           'encounter': 43,
#           'number': 15,
#           'creatures': 24,
#           'eras': 1,
#           'boarding': 17,
#           'blue': 19,
#           'mountains': 12,
#           'rapes': 1,
#           'jennie': 26,
#           'introuduced': 1,
#           'kelly': 35,
#           'go': 515,
#           'leaves': 70,
#           'limo': 2,
#           'aids': 6,
#           'entering': 8,
#           'labyrinth': 3,
#           'head': 74,
#           'agave': 5,
#           'carrying': 18,
#           'emilia': 5,
#           'character': 235,
#           'ethelred': 1,
#           'break': 92,
#           'hermit': 4,
#           'dwelling': 1,
#           'carter': 33,
#           'lilly': 12,
#           'visit': 100,
#           'see': 193,
#           '8': 3,
#           'mike': 72,
#           'quit': 19,
#           'devushkin': 9,
#           'occupation': 154,
#           'stows': 2,
#           'indian': 16,
#           'girl': 59,
#           'pirates': 19,
#           'horrified': 4,
#           'larbas': 1,
#           'slogan': 7,
#           'doe': 41,
#           'movement': 11,
#           'create': 31,
#           'tina': 8,
#           'lizzie': 24,
#           'punishment': 39,
#           'perjury': 1,
#           'sylvia': 38,
#           'letters': 39,
#           'written': 27,
#           'moonfleet': 2,
#           'located': 107,
#           'south': 18,
#           'alfred': 23,
#           'polly': 42,
#           'saved': 28,
#           'bankruptcy': 4,
#           'socrates': 22,
#           'decision': 17,
#           'cell': 19,
#           'unjust': 4,
#           'bar': 22,
#           'rick': 17,
#           'fred': 52,
#           'day': 134,
#           '6': 7,
#           'pass': 35,
#           'week': 17,
#           'nafertari': 3,
#           'promis': 1,
#           'norton': 6,
#           'underlying': 1,
#           'besides': 39,
#           'jimmy': 35,
#           'gator': 4,
#           'also': 31,
#           'cancer': 14,
#           'otis': 11,
#           'twins': 22,
#           'treat': 25,
#           'ghost': 43,
#           'connected': 10,
#           'robert': 62,
#           'maybold': 7,
#           'convince': 81,
#           'fancy': 13,
#           'withdraw': 4,
#           'engagement': 33,
#           'dick': 41,
#           'weather': 7,
#           'conditions': 6,
#           'innocent': 21,
#           'left': 112,
#           'baby': 59,
#           'craig': 17,
#           'lives': 49,
#           'next': 46,
#           'door': 38,
#           'chicago': 21,
#           'thugs': 5,
#           'corso': 7,
#           'confirm': 4,
#           'theory': 15,
#           'engravings': 5,
#           'rosaura': 7,
#           'appears': 29,
#           'falls': 72,
#           'three': 90,
#           'defendants': 7,
#           'charged': 16,
#           'time': 286,
#           '20': 9,
#           'oswald': 3,
#           'later': 40,
#           'cliff': 14,
#           'kidnap': 31,
#           'offer': 90,
#           'exchange': 35,
#           'dictabird': 1,
#           'candles': 7,
#           'stransum': 9,
#           'friend': 133,
#           'light': 14,
#           'altar': 5,
#           'gregory': 41,
#           'challenge': 37,
#           'central': 15,
#           'council': 24,
#           'icarus': 4,
#           'bomb': 37,
#           'unbeatable': 2,
#           'karl': 22,
#           'translation': 2,
#           'tarzan': 48,
#           'ape': 8,
#           'language': 29,
#           'tommy': 34,
#           'stubbins': 3,
#           'mathew': 1,
#           'muff': 1,
#           'out': 482,
#           'dolittle': 11,
#           'leonard': 40,
#           'tattoo': 1,
#           'disapprove': 6,
#           'pascal': 24,
#           'clotilde': 8,
#           'often': 22,
#           'predators': 7,
#           'marcelo': 9,
#           'choose': 59,
#           'defend': 13,
#           'german': 18,
#           'soldier': 17,
#           'annie': 74,
#           'randolph': 10,
#           'originally': 54,
#           'judea': 9,
#           'remain': 19,
#           'falmouth': 2,
#           'george': 175,
#           'learn': 119,
#           'logue': 10,
#           'coronation': 4,
#           'willow': 6,
#           'attempts': 30,
#           'cure': 15,
#           'raziel': 3,
#           'sailor': 17,
#           'bobby': 71,
#           'peru': 11,
#           'developing': 2,
#           'redding': 2,
#           'disappointed': 2,
#           'seeks': 10,
#           'church': 65,
#           'authority': 4,
#           'town': 119,
#           'maurya': 11,
#           'seek': 37,
#           'dark': 15,
#           'nights': 2,
#           'samhain': 1,
#           'archie': 24,
#           'anger': 10,
#           'daniel': 18,
#           'brewster': 27,
#           'names': 71,
#           'currer': 7,
#           'daughters': 41,
#           'giglio': 10,
#           'use': 277,
#           'hostage': 29,
#           'chelios': 12,
#           'planning': 39,
#           'retire': 8,
#           'berlin': 15,
#           'think': 187,
#           'owner': 45,
#           'must': 69,
#           'blind': 15,
#           'harry': 111,
#           'six': 16,
#           'months': 14,
#           'play': 138,
#           'paris': 51,
#           'graeme': 11,
#           'clive': 8,
#           'best': 58,
#           'selling': 10,
#           'novel': 30,
#           'most': 102,
#           'recent': 2,
#           'scene': 32,
#           'graham': 33,
#           'visits': 28,
#           'faisal': 1,
#           'pretend': 36,
#           'jeff': 42,
#           'stop': 87,
#           'thorwald': 7,
#           'throwald': 1,
#           'storms': 3,
#           'apartment': 44,
#           'old': 246,
#           'prison': 128,
#           'moll': 19,
#           'barton': 18,
#           'fink': 2,
#           'broadway': 3,
#           'called': 114,
#           'evan': 22,
#           'accepted': 10,
#           'college': 77,
#           'vice': 15,
#           'moppet': 15,
#           'injured': 44,
#           'can': 154,
#           'dragons': 9,
#           'nyssa': 2,
#           'suffers': 14,
#           'miscarriage': 2,
#           'samantha': 24,
#           'lost': 62,
#           'memory': 23,
#           'suggest': 41,
#           'movements': 1,
#           'should': 46,
#           'free': 49,
#           'spirited': 2,
#           'half': 20,
#           'main': 156,
#           'couple': 23,
#           'dante': 20,
#           'security': 29,
#           'shutters': 1,
#           'erik': 27,
#           'immediately': 18,
#           'arriving': 14,
#           'hy': 1,
#           'brasil': 1,
#           'working': 64,
#           'rent': 6,
#           'collector': 1,
#           'denry': 18,
#           'extra': 6,
#           'profit': 4,
#           'yog': 1,
#           'sothoth': 1,
#           'aeneas': 11,
#           'followers': 5,
#           'say': 163,
#           'ernest': 34,
#           'true': 67,
#           'identity': 61,
#           'zerophiliac': 2,
#           'morphic': 2,
#           'homes': 9,
#           'instruct': 16,
#           'camille': 6,
#           'spoiled': 2,
#           'known': 75,
#           'draco': 1,
#           'great': 38,
#           'hunca': 3,
#           'munca': 3,
#           'pay': 48,
#           'marines': 10,
#           'los': 22,
#           'angeles': 21,
#           'colorado': 2,
#           'geologists': 1,
#           'learned': 12,
#           'part': 102,
#           ...}),
#  'itos': ['<unk>',
#   '<pad>',
#   '<sos>',
#   '<eos>',
#   '?',
#   'the',
#   'what',
#   'to',
#   'does',
#   'is',
#   'who',
#   "'s",
#   'of',
#   'in',
#   'did',
#   'how',
#   'and',
#   'why',
#   'was',
#   'do',
#   'where',
#   'a',
#   'with',
#   'his',
#   'when',
#   'for',
#   ',',
#   'from',
#   'at',
#   'he',
#   'after',
#   'on',
#   'that',
#   'story',
#   'her',
#   'name',
#   'are',
#   'which',
#   'about',
#   'happens',
#   'as',
#   'have',
#   'by',
#   'up',
#   'him',
#   '"',
#   'end',
#   'be',
#   'get',
#   '-',
#   'take',
#   'she',
#   'many',
#   'find',
#   'go',
#   'first',
#   'father',
#   'into',
#   'out',
#   'they',
#   'die',
#   'their',
#   'want',
#   'has',
#   'kill',
#   'an',
#   'were',
#   'love',
#   'marry',
#   "'",
#   'before',
#   'killed',
#   'mr.',
#   'not',
#   'john',
#   'meet',
#   'being',
#   'house',
#   'job',
#   'live',
#   'this',
#   'death',
#   'family',
#   'while',
#   'will',
#   'wife',
#   'new',
#   'place',
#   'time',
#   'work',
#   'during',
#   'give',
#   'use',
#   'two',
#   'it',
#   'relationship',
#   'mother',
#   'money',
#   'become',
#   'tell',
#   'people',
#   'home',
#   'tom',
#   'kind',
#   'dr.',
#   'city',
#   'leave',
#   'back',
#   'happened',
#   'old',
#   'children',
#   'plan',
#   'one',
#   'character',
#   'mary',
#   'life',
#   'profession',
#   'man',
#   'make',
#   'long',
#   'help',
#   'whom',
#   ' ',
#   'jack',
#   'whose',
#   'king',
#   'mrs.',
#   "n't",
#   'beginning',
#   'ship',
#   'try',
#   'return',
#   'escape',
#   'type',
#   'war',
#   'believe',
#   'found',
#   'living',
#   'see',
#   'son',
#   'away',
#   'between',
#   'decide',
#   'kills',
#   'school',
#   'think',
#   'off',
#   'men',
#   'had',
#   'come',
#   'discover',
#   'group',
#   'lady',
#   'george',
#   'year',
#   'daughter',
#   'other',
#   'been',
#   'himself',
#   'david',
#   'over',
#   'say',
#   'much',
#   'country',
#   'doing',
#   'main',
#   'paul',
#   'can',
#   'husband',
#   'occupation',
#   'peter',
#   'car',
#   'police',
#   'sam',
#   'woman',
#   'crew',
#   'body',
#   'brother',
#   'fall',
#   'fight',
#   'henry',
#   'captain',
#   'causes',
#   'order',
#   'edward',
#   'play',
#   'last',
#   'travel',
#   'dies',
#   'day',
#   'island',
#   'friend',
#   'going',
#   'move',
#   'narrator',
#   'years',
#   'gets',
#   'if',
#   'them',
#   'party',
#   'prison',
#   'real',
#   'sent',
#   'set',
#   'feel',
#   'secret',
#   'night',
#   'show',
#   'ask',
#   'married',
#   'against',
#   'anna',
#   'william',
#   'would',
#   'down',
#   'finally',
#   'learn',
#   'town',
#   'charlie',
#   'joe',
#   'sir',
#   'call',
#   'state',
#   'called',
#   'died',
#   'team',
#   'left',
#   'so',
#   'harry',
#   'made',
#   'murder',
#   'anne',
#   'de',
#   'event',
#   'james',
#   'located',
#   'friends',
#   'jim',
#   'trying',
#   'dead',
#   'mark',
#   'queen',
#   'second',
#   'finds',
#   'most',
#   'part',
#   'way',
#   'arrested',
#   'bill',
#   'martin',
#   'only',
#   'all',
#   'goes',
#   'person',
#   'steal',
#   'visit',
#   'adam',
#   'marriage',
#   'send',
#   'final',
#   'run',
#   'through',
#   'attack',
#   'start',
#   'world',
#   'affair',
#   'eventually',
#   'given',
#   'frank',
#   'used',
#   'break',
#   'nick',
#   'parents',
#   'related',
#   'earth',
#   'michael',
#   'tells',
#   'billy',
#   'offer',
#   'three',
#   'like',
#   'max',
#   'save',
#   'becomes',
#   'begin',
#   'happen',
#   'makes',
#   'sister',
#   'takes',
#   'conan',
#   'stop',
#   'turn',
#   'upon',
#   'white',
#   'initially',
#   'know',
#   'room',
#   'attempt',
#   'battle',
#   'child',
#   'suicide',
#   'together',
#   'eve',
#   'title',
#   'caused',
#   'having',
#   'once',
#   'promise',
#   'convince',
#   'land',
#   'returns',
#   'leaving',
#   'lose',
#   'realize',
#   'army',
#   'laura',
#   'taken',
#   'under',
#   'crime',
#   'dog',
#   'nickname',
#   'college',
#   'company',
#   'hospital',
#   'receive',
#   'rescue',
#   'rose',
#   'able',
#   'helps',
#   'jerry',
#   'lord',
#   'position',
#   'reason',
#   'sarah',
#   '.',
#   'according',
#   'brothers',
#   'killing',
#   'known',
#   'more',
#   'planet',
#   'put',
#   'stay',
#   'there',
#   'annie',
#   'ben',
#   'characters',
#   'head',
#   'business',
#   'involved',
#   'kate',
#   'london',
#   'need',
#   'princess',
#   'really',
#   'reveal',
#   'shot',
#   'change',
#   'falls',
#   'letter',
#   'mike',
#   'miss',
#   'own',
#   'phil',
#   'ruth',
#   'tries',
#   'trip',
#   'wedding',
#   'young',
#   'bobby',
#   'charles',
#   'jane',
#   'names',
#   'game',
#   'leaves',
#   'ray',
#   'fire',
#   'hotel',
#   'keep',
#   'must',
#   'prince',
#   'animal',
#   'case',
#   'ed',
#   'luke',
#   'cause',
#   'smith',
#   'true',
#   'buy',
#   'claim',
#   'emily',
#   'engaged',
#   'walter',
#   'church',
#   'elizabeth',
#   'herself',
#   'stephen',
#   'wants',
#   'york',
#   'bring',
#   'carl',
#   'general',
#   'hide',
#   'president',
#   'states',
#   'told',
#   'win',
#   'working',
#   'bishop',
#   'comes',
#   'discovered',
#   'each',
#   'hand',
#   'lost',
#   'robert',
#   'wish',
#   'captured',
#   'clara',
#   'dream',
#   'identity',
#   'instead',
#   'join',
#   'marrying',
#   'supposed',
#   'actually',
#   'agree',
#   'ann',
#   'court',
#   'dorothy',
#   'lead',
#   'linda',
#   'mission',
#   'refuse',
#   'richard',
#   'agent',
#   'baby',
#   'career',
#   'choose',
#   'girl',
#   'gives',
#   'law',
#   'lucy',
#   'margaret',
#   'rebecca',
#   'than',
#   'women',
#   'alien',
#   'best',
#   'black',
#   'girlfriend',
#   'government',
#   'alex',
#   'england',
#   'god',
#   'maggie',
#   'trial',
#   'again',
#   'commit',
#   'could',
#   'doctor',
#   'ends',
#   'flee',
#   'leader',
#   'louis',
#   'red',
#   'spend',
#   'bob',
#   'castle',
#   'else',
#   'fired',
#   'getting',
#   'helen',
#   'jason',
#   'looking',
#   'meeting',
#   'protagonist',
#   'react',
#   'saves',
#   'station',
#   'support',
#   'uncle',
#   'united',
#   'weapon',
#   'gang',
#   'high',
#   'missing',
#   'originally',
#   'rob',
#   'stolen',
#   'club',
#   'duke',
#   'force',
#   'former',
#   'got',
#   'la',
#   'train',
#   'village',
#   'drug',
#   'emma',
#   'fred',
#   'jackie',
#   'military',
#   'power',
#   'shoot',
#   'ted',
#   'ultimately',
#   'behind',
#   'boat',
#   'crash',
#   'destroy',
#   'paris',
#   'scott',
#   'sex',
#   'society',
#   'taking',
#   'age',
#   'ca',
#   'forced',
#   'future',
#   'held',
#   'hire',
#   'jacob',
#   'leads',
#   'ralph',
#   'sees',
#   'some',
#   'suspect',
#   'andrew',
#   'arrives',
#   'date',
#   'dying',
#   'face',
#   'free',
#   'lives',
#   'rescued',
#   'role',
#   'sea',
#   'sell',
#   'took',
#   'creature',
#   'ellen',
#   'grace',
#   'helped',
#   'jean',
#   'look',
#   'louise',
#   'officer',
#   'pay',
#   'result',
#   'tarzan',
#   'thing',
#   'things',
#   'water',
#   'alice',
#   'around',
#   'camp',
#   'colonel',
#   'estate',
#   'fbi',
#   'form',
#   'item',
#   'major',
#   'mr',
#   'norman',
#   'plane',
#   'store',
#   'thomas',
#   'write',
#   'building',
#   'holly',
#   'meets',
#   'next',
#   'no',
#   'river',
#   'robin',
#   'shoots',
#   'should',
#   'steve',
#   'stu',
#   'you',
#   'accident',
#   'box',
#   'chris',
#   'discovers',
#   'information',
#   'lee',
#   'members',
#   'owner',
#   'responsible',
#   'upset',
#   'accused',
#   'anthony',
#   'apartment',
#   'became',
#   'benjamin',
#   'charlotte',
#   'count',
#   'danny',
#   'dean',
#   'injured',
#   'jake',
#   'joan',
#   'mind',
#   'murdered',
#   'revealed',
#   'went',
#   'ali',
#   'arthur',
#   'ashe',
#   'attend',
#   'aunt',
#   'boss',
#   'both',
#   'detective',
#   'encounter',
#   'four',
#   'gain',
#   'ghost',
#   'holmes',
#   'jones',
#   'little',
#   'named',
#   'news',
#   'past',
#   'plans',
#   'rachel',
#   'regarding',
#   'space',
#   'susan',
#   'virginia',
#   'wanted',
#   'act',
#   'allow',
#   'blood',
#   'farm',
#   'humans',
#   'jeff',
#   'polly',
#   'returning',
#   'ripley',
#   'song',
#   'special',
#   'truth',
#   'amy',
#   'boy',
#   'created',
#   'daughters',
#   'dick',
#   'doe',
#   'enter',
#   'gregory',
#   'human',
#   'just',
#   'leo',
#   'maria',
#   'nationality',
#   'propose',
#   'sort',
#   'suggest',
#   'works',
#   'arrive',
#   'attacks',
#   'bank',
#   'blame',
#   'capture',
#   'deal',
#   'destroyed',
#   'duel',
#   'felix',
#   'hired',
#   'jail',
#   'later',
#   'leonard',
#   'lover',
#   'park',
#   'ross',
#   'suffer',
#   'assigned',
#   'base',
#   'besides',
#   'build',
#   'cole',
#   'isabel',
#   'letters',
#   'partner',
#   'phillip',
#   'planning',
#   'punishment',
#   'shop',
#   'teach',
#   'threaten',
#   'van',
#   'wear',
#   'class',
#   'claude',
#   'close',
#   'door',
#   'ex',
#   'fighting',
#   'great',
#   'hold',
#   'kid',
#   'kidnapped',
#   'led',
#   'marie',
#   'member',
#   'met',
#   'office',
#   'powers',
#   'soldiers',
#   'sylvia',
#   'america',
#   'another',
#   'big',
#   'bomb',
#   'bruce',
#   'challenge',
#   'charley',
#   'dinner',
#   'gabriel',
#   'gift',
#   'good',
#   'harold',
#   'local',
#   'marcus',
#   'never',
#   'returned',
#   'right',
#   'seek',
#   'accept',
#   'but',
#   'calls',
#   'care',
#   'considered',
#   'dale',
#   'defeat',
#   'described',
#   'divorce',
#   'gun',
#   'idea',
#   'killer',
#   'phone',
#   'pretend',
#   'proposal',
#   'protect',
#   'purpose',
#   'reach',
#   'revenge',
#   'shows',
#   'simon',
#   'traveling',
#   'american',
#   'andy',
#   'attacked',
#   'baron',
#   'barry',
#   'because',
#   'begins',
#   'cat',
#   'chief',
#   'control',
#   'exchange',
#   'follow',
#   'gold',
#   'important',
#   'intend',
#   'jenny',
#   'jimmy',
#   'judge',
#   'kelly',
#   'kirk',
#   'lieutenant',
#   'medical',
#   'near',
#   'pass',
#   'pete',
#   'playing',
#   'relation',
#   'roy',
#   'stone',
#   'times',
#   'towards',
#   'us',
#   'ash',
#   'avoid',
#   'bed',
#   'blade',
#   'bourne',
#   'caught',
#   'color',
#   'condition',
#   'english',
#   'ernest',
#   'evidence',
#   'fairy',
#   'gave',
#   'grandfather',
#   'hidden',
#   'inside',
#   'moon',
#   'pierre',
#   'problem',
#   'released',
#   'st.',
#   'tommy',
#   'we',
#   'accidentally',
#   'arnold',
#   'art',
#   'captures',
#   'carter',
#   'describe',
#   'dr',
#   'engagement',
#   'evil',
#   'feelings',
#   'funeral',
#   'graham',
#   'grant',
#   'hall',
#   'heart',
#   'hiding',
#   'malcolm',
#   'original',
#   'patrick',
#   'point',
#   'professor',
#   'rescues',
#   'respond',
#   'setting',
#   'steven',
#   'still',
#   'talk',
#   'tyler',
#   'watch',
#   'ball',
#   'bond',
#   'christopher',
#   'cindy',
#   'ethan',
#   'everyone',
#   'fake',
#   'finn',
#   'grow',
#   'kitty',
#   'lambert',
#   'madame',
#   'maurice',
#   'maya',
#   'read',
#   'ring',
#   'rita',
#   'robbery',
#   'scene',
#   'share',
#   'storm',
#   'tried',
#   'vehicle',
#   'witness',
#   'wrong',
#   'also',
#   'appear',
#   'born',
#   'century',
#   'contact',
#   'cover',
#   'create',
#   'different',
#   'disease',
#   'earl',
#   'eric',
#   'forest',
#   'france',
#   'hear',
#   'hit',
#   'hope',
#   'inherit',
#   'interest',
#   'interested',
#   'invite',
#   'josh',
#   'kidnap',
#   'larry',
#   'let',
#   'marries',
#   'message',
#   'molly',
#   'ned',
#   'newspaper',
#   'oscar',
#   'others',
#   'priest',
#   'searching',
#   'silas',
#   'survive',
#   'vampire',
#   'video',
#   'vitti',
#   'writing',
#   'air',
#   'arrest',
#   'attempts',
#   'band',
#   'built',
#   'came',
#   'catch',
#   'emperor',
#   'escaped',
#   'escapes',
#   'field',
#   'fortune',
#   'garden',
#   'ginger',
#   'gordon',
#   'harriet',
#   'history',
#   'juno',
#   'lie',
#   'matt',
#   'miles',
#   'miller',
#   'mrs',
#   'native',
#   'novel',
#   'philip',
#   'religion',
#   'sends',
#   'serve',
#   'sisters',
#   'star',
#   'students',
#   'taylor',
#   'trade',
#   'trick',
#   'wall',
#   'well',
#   'wrote',
#   '$',
#   'along',
#   'appears',
#   'even',
#   'forces',
#   'french',
#   'girls',
#   'happening',
#   'hermann',
#   'hostage',
#   'language',
#   'lawyer',
#   'mars',
#   'present',
#   'purchase',
#   'ride',
#   'robinson',
#   'said',
#   'same',
#   'security',
#   'slave',
#   'someone',
#   'stories',
#   'themselves',
#   'travis',
#   'valentine',
#   'across',
#   'airport',
#   'almost',
#   'boyfriend',
#   'brought',
#   'chance',
#   'childhood',
#   'coming',
#   'convinces',
#   'dave',
#   'eddie',
#   'its',
#   'jamie',
#   'kane',
#   'location',
#   'making',
#   'may',
#   'object',
#   'piece',
#   'raised',
#   'romantic',
#   'rudy',
#   'saved',
#   'sebastian',
#   'sentence',
#   'since',
#   'sleep',
#   'system',
#   'visits',
#   'wearing',
#   'action',
#   'alan',
#   'aliens',
#   'animals',
#   'attempting',
#   'bella',
#   'better',
#   ...],
#  'stoi': defaultdict(<function torchtext.vocab._default_unk_index>,
#              {'<unk>': 0,
#               '<pad>': 1,
#               '<sos>': 2,
#               '<eos>': 3,
#               '?': 4,
#               'the': 5,
#               'what': 6,
#               'to': 7,
#               'does': 8,
#               'is': 9,
#               'who': 10,
#               "'s": 11,
#               'of': 12,
#               'in': 13,
#               'did': 14,
#               'how': 15,
#               'and': 16,
#               'why': 17,
#               'was': 18,
#               'do': 19,
#               'where': 20,
#               'a': 21,
#               'with': 22,
#               'his': 23,
#               'when': 24,
#               'for': 25,
#               ',': 26,
#               'from': 27,
#               'at': 28,
#               'he': 29,
#               'after': 30,
#               'on': 31,
#               'that': 32,
#               'story': 33,
#               'her': 34,
#               'name': 35,
#               'are': 36,
#               'which': 37,
#               'about': 38,
#               'happens': 39,
#               'as': 40,
#               'have': 41,
#               'by': 42,
#               'up': 43,
#               'him': 44,
#               '"': 45,
#               'end': 46,
#               'be': 47,
#               'get': 48,
#               '-': 49,
#               'take': 50,
#               'she': 51,
#               'many': 52,
#               'find': 53,
#               'go': 54,
#               'first': 55,
#               'father': 56,
#               'into': 57,
#               'out': 58,
#               'they': 59,
#               'die': 60,
#               'their': 61,
#               'want': 62,
#               'has': 63,
#               'kill': 64,
#               'an': 65,
#               'were': 66,
#               'love': 67,
#               'marry': 68,
#               "'": 69,
#               'before': 70,
#               'killed': 71,
#               'mr.': 72,
#               'not': 73,
#               'john': 74,
#               'meet': 75,
#               'being': 76,
#               'house': 77,
#               'job': 78,
#               'live': 79,
#               'this': 80,
#               'death': 81,
#               'family': 82,
#               'while': 83,
#               'will': 84,
#               'wife': 85,
#               'new': 86,
#               'place': 87,
#               'time': 88,
#               'work': 89,
#               'during': 90,
#               'give': 91,
#               'use': 92,
#               'two': 93,
#               'it': 94,
#               'relationship': 95,
#               'mother': 96,
#               'money': 97,
#               'become': 98,
#               'tell': 99,
#               'people': 100,
#               'home': 101,
#               'tom': 102,
#               'kind': 103,
#               'dr.': 104,
#               'city': 105,
#               'leave': 106,
#               'back': 107,
#               'happened': 108,
#               'old': 109,
#               'children': 110,
#               'plan': 111,
#               'one': 112,
#               'character': 113,
#               'mary': 114,
#               'life': 115,
#               'profession': 116,
#               'man': 117,
#               'make': 118,
#               'long': 119,
#               'help': 120,
#               'whom': 121,
#               ' ': 122,
#               'jack': 123,
#               'whose': 124,
#               'king': 125,
#               'mrs.': 126,
#               "n't": 127,
#               'beginning': 128,
#               'ship': 129,
#               'try': 130,
#               'return': 131,
#               'escape': 132,
#               'type': 133,
#               'war': 134,
#               'believe': 135,
#               'found': 136,
#               'living': 137,
#               'see': 138,
#               'son': 139,
#               'away': 140,
#               'between': 141,
#               'decide': 142,
#               'kills': 143,
#               'school': 144,
#               'think': 145,
#               'off': 146,
#               'men': 147,
#               'had': 148,
#               'come': 149,
#               'discover': 150,
#               'group': 151,
#               'lady': 152,
#               'george': 153,
#               'year': 154,
#               'daughter': 155,
#               'other': 156,
#               'been': 157,
#               'himself': 158,
#               'david': 159,
#               'over': 160,
#               'say': 161,
#               'much': 162,
#               'country': 163,
#               'doing': 164,
#               'main': 165,
#               'paul': 166,
#               'can': 167,
#               'husband': 168,
#               'occupation': 169,
#               'peter': 170,
#               'car': 171,
#               'police': 172,
#               'sam': 173,
#               'woman': 174,
#               'crew': 175,
#               'body': 176,
#               'brother': 177,
#               'fall': 178,
#               'fight': 179,
#               'henry': 180,
#               'captain': 181,
#               'causes': 182,
#               'order': 183,
#               'edward': 184,
#               'play': 185,
#               'last': 186,
#               'travel': 187,
#               'dies': 188,
#               'day': 189,
#               'island': 190,
#               'friend': 191,
#               'going': 192,
#               'move': 193,
#               'narrator': 194,
#               'years': 195,
#               'gets': 196,
#               'if': 197,
#               'them': 198,
#               'party': 199,
#               'prison': 200,
#               'real': 201,
#               'sent': 202,
#               'set': 203,
#               'feel': 204,
#               'secret': 205,
#               'night': 206,
#               'show': 207,
#               'ask': 208,
#               'married': 209,
#               'against': 210,
#               'anna': 211,
#               'william': 212,
#               'would': 213,
#               'down': 214,
#               'finally': 215,
#               'learn': 216,
#               'town': 217,
#               'charlie': 218,
#               'joe': 219,
#               'sir': 220,
#               'call': 221,
#               'state': 222,
#               'called': 223,
#               'died': 224,
#               'team': 225,
#               'left': 226,
#               'so': 227,
#               'harry': 228,
#               'made': 229,
#               'murder': 230,
#               'anne': 231,
#               'de': 232,
#               'event': 233,
#               'james': 234,
#               'located': 235,
#               'friends': 236,
#               'jim': 237,
#               'trying': 238,
#               'dead': 239,
#               'mark': 240,
#               'queen': 241,
#               'second': 242,
#               'finds': 243,
#               'most': 244,
#               'part': 245,
#               'way': 246,
#               'arrested': 247,
#               'bill': 248,
#               'martin': 249,
#               'only': 250,
#               'all': 251,
#               'goes': 252,
#               'person': 253,
#               'steal': 254,
#               'visit': 255,
#               'adam': 256,
#               'marriage': 257,
#               'send': 258,
#               'final': 259,
#               'run': 260,
#               'through': 261,
#               'attack': 262,
#               'start': 263,
#               'world': 264,
#               'affair': 265,
#               'eventually': 266,
#               'given': 267,
#               'frank': 268,
#               'used': 269,
#               'break': 270,
#               'nick': 271,
#               'parents': 272,
#               'related': 273,
#               'earth': 274,
#               'michael': 275,
#               'tells': 276,
#               'billy': 277,
#               'offer': 278,
#               'three': 279,
#               'like': 280,
#               'max': 281,
#               'save': 282,
#               'becomes': 283,
#               'begin': 284,
#               'happen': 285,
#               'makes': 286,
#               'sister': 287,
#               'takes': 288,
#               'conan': 289,
#               'stop': 290,
#               'turn': 291,
#               'upon': 292,
#               'white': 293,
#               'initially': 294,
#               'know': 295,
#               'room': 296,
#               'attempt': 297,
#               'battle': 298,
#               'child': 299,
#               'suicide': 300,
#               'together': 301,
#               'eve': 302,
#               'title': 303,
#               'caused': 304,
#               'having': 305,
#               'once': 306,
#               'promise': 307,
#               'convince': 308,
#               'land': 309,
#               'returns': 310,
#               'leaving': 311,
#               'lose': 312,
#               'realize': 313,
#               'army': 314,
#               'laura': 315,
#               'taken': 316,
#               'under': 317,
#               'crime': 318,
#               'dog': 319,
#               'nickname': 320,
#               'college': 321,
#               'company': 322,
#               'hospital': 323,
#               'receive': 324,
#               'rescue': 325,
#               'rose': 326,
#               'able': 327,
#               'helps': 328,
#               'jerry': 329,
#               'lord': 330,
#               'position': 331,
#               'reason': 332,
#               'sarah': 333,
#               '.': 334,
#               'according': 335,
#               'brothers': 336,
#               'killing': 337,
#               'known': 338,
#               'more': 339,
#               'planet': 340,
#               'put': 341,
#               'stay': 342,
#               'there': 343,
#               'annie': 344,
#               'ben': 345,
#               'characters': 346,
#               'head': 347,
#               'business': 348,
#               'involved': 349,
#               'kate': 350,
#               'london': 351,
#               'need': 352,
#               'princess': 353,
#               'really': 354,
#               'reveal': 355,
#               'shot': 356,
#               'change': 357,
#               'falls': 358,
#               'letter': 359,
#               'mike': 360,
#               'miss': 361,
#               'own': 362,
#               'phil': 363,
#               'ruth': 364,
#               'tries': 365,
#               'trip': 366,
#               'wedding': 367,
#               'young': 368,
#               'bobby': 369,
#               'charles': 370,
#               'jane': 371,
#               'names': 372,
#               'game': 373,
#               'leaves': 374,
#               'ray': 375,
#               'fire': 376,
#               'hotel': 377,
#               'keep': 378,
#               'must': 379,
#               'prince': 380,
#               'animal': 381,
#               'case': 382,
#               'ed': 383,
#               'luke': 384,
#               'cause': 385,
#               'smith': 386,
#               'true': 387,
#               'buy': 388,
#               'claim': 389,
#               'emily': 390,
#               'engaged': 391,
#               'walter': 392,
#               'church': 393,
#               'elizabeth': 394,
#               'herself': 395,
#               'stephen': 396,
#               'wants': 397,
#               'york': 398,
#               'bring': 399,
#               'carl': 400,
#               'general': 401,
#               'hide': 402,
#               'president': 403,
#               'states': 404,
#               'told': 405,
#               'win': 406,
#               'working': 407,
#               'bishop': 408,
#               'comes': 409,
#               'discovered': 410,
#               'each': 411,
#               'hand': 412,
#               'lost': 413,
#               'robert': 414,
#               'wish': 415,
#               'captured': 416,
#               'clara': 417,
#               'dream': 418,
#               'identity': 419,
#               'instead': 420,
#               'join': 421,
#               'marrying': 422,
#               'supposed': 423,
#               'actually': 424,
#               'agree': 425,
#               'ann': 426,
#               'court': 427,
#               'dorothy': 428,
#               'lead': 429,
#               'linda': 430,
#               'mission': 431,
#               'refuse': 432,
#               'richard': 433,
#               'agent': 434,
#               'baby': 435,
#               'career': 436,
#               'choose': 437,
#               'girl': 438,
#               'gives': 439,
#               'law': 440,
#               'lucy': 441,
#               'margaret': 442,
#               'rebecca': 443,
#               'than': 444,
#               'women': 445,
#               'alien': 446,
#               'best': 447,
#               'black': 448,
#               'girlfriend': 449,
#               'government': 450,
#               'alex': 451,
#               'england': 452,
#               'god': 453,
#               'maggie': 454,
#               'trial': 455,
#               'again': 456,
#               'commit': 457,
#               'could': 458,
#               'doctor': 459,
#               'ends': 460,
#               'flee': 461,
#               'leader': 462,
#               'louis': 463,
#               'red': 464,
#               'spend': 465,
#               'bob': 466,
#               'castle': 467,
#               'else': 468,
#               'fired': 469,
#               'getting': 470,
#               'helen': 471,
#               'jason': 472,
#               'looking': 473,
#               'meeting': 474,
#               'protagonist': 475,
#               'react': 476,
#               'saves': 477,
#               'station': 478,
#               'support': 479,
#               'uncle': 480,
#               'united': 481,
#               'weapon': 482,
#               'gang': 483,
#               'high': 484,
#               'missing': 485,
#               'originally': 486,
#               'rob': 487,
#               'stolen': 488,
#               'club': 489,
#               'duke': 490,
#               'force': 491,
#               'former': 492,
#               'got': 493,
#               'la': 494,
#               'train': 495,
#               'village': 496,
#               'drug': 497,
#               'emma': 498,
#               'fred': 499,
#               'jackie': 500,
#               'military': 501,
#               'power': 502,
#               'shoot': 503,
#               'ted': 504,
#               'ultimately': 505,
#               'behind': 506,
#               'boat': 507,
#               'crash': 508,
#               'destroy': 509,
#               'paris': 510,
#               'scott': 511,
#               'sex': 512,
#               'society': 513,
#               'taking': 514,
#               'age': 515,
#               'ca': 516,
#               'forced': 517,
#               'future': 518,
#               'held': 519,
#               'hire': 520,
#               'jacob': 521,
#               'leads': 522,
#               'ralph': 523,
#               'sees': 524,
#               'some': 525,
#               'suspect': 526,
#               'andrew': 527,
#               'arrives': 528,
#               'date': 529,
#               'dying': 530,
#               'face': 531,
#               'free': 532,
#               'lives': 533,
#               'rescued': 534,
#               'role': 535,
#               'sea': 536,
#               'sell': 537,
#               'took': 538,
#               'creature': 539,
#               'ellen': 540,
#               'grace': 541,
#               'helped': 542,
#               'jean': 543,
#               'look': 544,
#               'louise': 545,
#               'officer': 546,
#               'pay': 547,
#               'result': 548,
#               'tarzan': 549,
#               'thing': 550,
#               'things': 551,
#               'water': 552,
#               'alice': 553,
#               'around': 554,
#               'camp': 555,
#               'colonel': 556,
#               'estate': 557,
#               'fbi': 558,
#               'form': 559,
#               'item': 560,
#               'major': 561,
#               'mr': 562,
#               'norman': 563,
#               'plane': 564,
#               'store': 565,
#               'thomas': 566,
#               'write': 567,
#               'building': 568,
#               'holly': 569,
#               'meets': 570,
#               'next': 571,
#               'no': 572,
#               'river': 573,
#               'robin': 574,
#               'shoots': 575,
#               'should': 576,
#               'steve': 577,
#               'stu': 578,
#               'you': 579,
#               'accident': 580,
#               'box': 581,
#               'chris': 582,
#               'discovers': 583,
#               'information': 584,
#               'lee': 585,
#               'members': 586,
#               'owner': 587,
#               'responsible': 588,
#               'upset': 589,
#               'accused': 590,
#               'anthony': 591,
#               'apartment': 592,
#               'became': 593,
#               'benjamin': 594,
#               'charlotte': 595,
#               'count': 596,
#               'danny': 597,
#               'dean': 598,
#               'injured': 599,
#               'jake': 600,
#               'joan': 601,
#               'mind': 602,
#               'murdered': 603,
#               'revealed': 604,
#               'went': 605,
#               'ali': 606,
#               'arthur': 607,
#               'ashe': 608,
#               'attend': 609,
#               'aunt': 610,
#               'boss': 611,
#               'both': 612,
#               'detective': 613,
#               'encounter': 614,
#               'four': 615,
#               'gain': 616,
#               'ghost': 617,
#               'holmes': 618,
#               'jones': 619,
#               'little': 620,
#               'named': 621,
#               'news': 622,
#               'past': 623,
#               'plans': 624,
#               'rachel': 625,
#               'regarding': 626,
#               'space': 627,
#               'susan': 628,
#               'virginia': 629,
#               'wanted': 630,
#               'act': 631,
#               'allow': 632,
#               'blood': 633,
#               'farm': 634,
#               'humans': 635,
#               'jeff': 636,
#               'polly': 637,
#               'returning': 638,
#               'ripley': 639,
#               'song': 640,
#               'special': 641,
#               'truth': 642,
#               'amy': 643,
#               'boy': 644,
#               'created': 645,
#               'daughters': 646,
#               'dick': 647,
#               'doe': 648,
#               'enter': 649,
#               'gregory': 650,
#               'human': 651,
#               'just': 652,
#               'leo': 653,
#               'maria': 654,
#               'nationality': 655,
#               'propose': 656,
#               'sort': 657,
#               'suggest': 658,
#               'works': 659,
#               'arrive': 660,
#               'attacks': 661,
#               'bank': 662,
#               'blame': 663,
#               'capture': 664,
#               'deal': 665,
#               'destroyed': 666,
#               'duel': 667,
#               'felix': 668,
#               'hired': 669,
#               'jail': 670,
#               'later': 671,
#               'leonard': 672,
#               'lover': 673,
#               'park': 674,
#               'ross': 675,
#               'suffer': 676,
#               'assigned': 677,
#               'base': 678,
#               'besides': 679,
#               'build': 680,
#               'cole': 681,
#               'isabel': 682,
#               'letters': 683,
#               'partner': 684,
#               'phillip': 685,
#               'planning': 686,
#               'punishment': 687,
#               'shop': 688,
#               'teach': 689,
#               'threaten': 690,
#               'van': 691,
#               'wear': 692,
#               'class': 693,
#               'claude': 694,
#               'close': 695,
#               'door': 696,
#               'ex': 697,
#               'fighting': 698,
#               'great': 699,
#               'hold': 700,
#               'kid': 701,
#               'kidnapped': 702,
#               'led': 703,
#               'marie': 704,
#               'member': 705,
#               'met': 706,
#               'office': 707,
#               'powers': 708,
#               'soldiers': 709,
#               'sylvia': 710,
#               'america': 711,
#               'another': 712,
#               'big': 713,
#               'bomb': 714,
#               'bruce': 715,
#               'challenge': 716,
#               'charley': 717,
#               'dinner': 718,
#               'gabriel': 719,
#               'gift': 720,
#               'good': 721,
#               'harold': 722,
#               'local': 723,
#               'marcus': 724,
#               'never': 725,
#               'returned': 726,
#               'right': 727,
#               'seek': 728,
#               'accept': 729,
#               'but': 730,
#               'calls': 731,
#               'care': 732,
#               'considered': 733,
#               'dale': 734,
#               'defeat': 735,
#               'described': 736,
#               'divorce': 737,
#               'gun': 738,
#               'idea': 739,
#               'killer': 740,
#               'phone': 741,
#               'pretend': 742,
#               'proposal': 743,
#               'protect': 744,
#               'purpose': 745,
#               'reach': 746,
#               'revenge': 747,
#               'shows': 748,
#               'simon': 749,
#               'traveling': 750,
#               'american': 751,
#               'andy': 752,
#               'attacked': 753,
#               'baron': 754,
#               'barry': 755,
#               'because': 756,
#               'begins': 757,
#               'cat': 758,
#               'chief': 759,
#               'control': 760,
#               'exchange': 761,
#               'follow': 762,
#               'gold': 763,
#               'important': 764,
#               'intend': 765,
#               'jenny': 766,
#               'jimmy': 767,
#               'judge': 768,
#               'kelly': 769,
#               'kirk': 770,
#               'lieutenant': 771,
#               'medical': 772,
#               'near': 773,
#               'pass': 774,
#               'pete': 775,
#               'playing': 776,
#               'relation': 777,
#               'roy': 778,
#               'stone': 779,
#               'times': 780,
#               'towards': 781,
#               'us': 782,
#               'ash': 783,
#               'avoid': 784,
#               'bed': 785,
#               'blade': 786,
#               'bourne': 787,
#               'caught': 788,
#               'color': 789,
#               'condition': 790,
#               'english': 791,
#               'ernest': 792,
#               'evidence': 793,
#               'fairy': 794,
#               'gave': 795,
#               'grandfather': 796,
#               'hidden': 797,
#               'inside': 798,
#               'moon': 799,
#               'pierre': 800,
#               'problem': 801,
#               'released': 802,
#               'st.': 803,
#               'tommy': 804,
#               'we': 805,
#               'accidentally': 806,
#               'arnold': 807,
#               'art': 808,
#               'captures': 809,
#               'carter': 810,
#               'describe': 811,
#               'dr': 812,
#               'engagement': 813,
#               'evil': 814,
#               'feelings': 815,
#               'funeral': 816,
#               'graham': 817,
#               'grant': 818,
#               'hall': 819,
#               'heart': 820,
#               'hiding': 821,
#               'malcolm': 822,
#               'original': 823,
#               'patrick': 824,
#               'point': 825,
#               'professor': 826,
#               'rescues': 827,
#               'respond': 828,
#               'setting': 829,
#               'steven': 830,
#               'still': 831,
#               'talk': 832,
#               'tyler': 833,
#               'watch': 834,
#               'ball': 835,
#               'bond': 836,
#               'christopher': 837,
#               'cindy': 838,
#               'ethan': 839,
#               'everyone': 840,
#               'fake': 841,
#               'finn': 842,
#               'grow': 843,
#               'kitty': 844,
#               'lambert': 845,
#               'madame': 846,
#               'maurice': 847,
#               'maya': 848,
#               'read': 849,
#               'ring': 850,
#               'rita': 851,
#               'robbery': 852,
#               'scene': 853,
#               'share': 854,
#               'storm': 855,
#               'tried': 856,
#               'vehicle': 857,
#               'witness': 858,
#               'wrong': 859,
#               'also': 860,
#               'appear': 861,
#               'born': 862,
#               'century': 863,
#               'contact': 864,
#               'cover': 865,
#               'create': 866,
#               'different': 867,
#               'disease': 868,
#               'earl': 869,
#               'eric': 870,
#               'forest': 871,
#               'france': 872,
#               'hear': 873,
#               'hit': 874,
#               'hope': 875,
#               'inherit': 876,
#               'interest': 877,
#               'interested': 878,
#               'invite': 879,
#               'josh': 880,
#               'kidnap': 881,
#               'larry': 882,
#               'let': 883,
#               'marries': 884,
#               'message': 885,
#               'molly': 886,
#               'ned': 887,
#               'newspaper': 888,
#               'oscar': 889,
#               'others': 890,
#               'priest': 891,
#               'searching': 892,
#               'silas': 893,
#               'survive': 894,
#               'vampire': 895,
#               'video': 896,
#               'vitti': 897,
#               'writing': 898,
#               'air': 899,
#               'arrest': 900,
#               'attempts': 901,
#               'band': 902,
#               'built': 903,
#               'came': 904,
#               'catch': 905,
#               'emperor': 906,
#               'escaped': 907,
#               'escapes': 908,
#               'field': 909,
#               'fortune': 910,
#               'garden': 911,
#               'ginger': 912,
#               'gordon': 913,
#               'harriet': 914,
#               'history': 915,
#               'juno': 916,
#               'lie': 917,
#               'matt': 918,
#               'miles': 919,
#               'miller': 920,
#               'mrs': 921,
#               'native': 922,
#               'novel': 923,
#               'philip': 924,
#               'religion': 925,
#               'sends': 926,
#               'serve': 927,
#               'sisters': 928,
#               'star': 929,
#               'students': 930,
#               'taylor': 931,
#               'trade': 932,
#               'trick': 933,
#               'wall': 934,
#               'well': 935,
#               'wrote': 936,
#               '$': 937,
#               'along': 938,
#               'appears': 939,
#               'even': 940,
#               'forces': 941,
#               'french': 942,
#               'girls': 943,
#               'happening': 944,
#               'hermann': 945,
#               'hostage': 946,
#               'language': 947,
#               'lawyer': 948,
#               'mars': 949,
#               'present': 950,
#               'purchase': 951,
#               'ride': 952,
#               'robinson': 953,
#               'said': 954,
#               'same': 955,
#               'security': 956,
#               'slave': 957,
#               'someone': 958,
#               'stories': 959,
#               'themselves': 960,
#               'travis': 961,
#               'valentine': 962,
#               'across': 963,
#               'airport': 964,
#               'almost': 965,
#               'boyfriend': 966,
#               'brought': 967,
#               'chance': 968,
#               'childhood': 969,
#               'coming': 970,
#               'convinces': 971,
#               'dave': 972,
#               'eddie': 973,
#               'its': 974,
#               'jamie': 975,
#               'kane': 976,
#               'location': 977,
#               'making': 978,
#               'may': 979,
#               'object': 980,
#               'piece': 981,
#               'raised': 982,
#               'romantic': 983,
#               'rudy': 984,
#               'saved': 985,
#               'sebastian': 986,
#               'sentence': 987,
#               'since': 988,
#               'sleep': 989,
#               'system': 990,
#               'visits': 991,
#               'wearing': 992,
#               'action': 993,
#               'alan': 994,
#               'aliens': 995,
#               'animals': 996,
#               'attempting': 997,
#               'bella': 998,
#               'better': 999,
#               ...}),
#  'vectors': None}

# %% [markdown]
# ### Create iterators for train, valid and test.
#
# BucketIterator is used instead of Standard Iterator. BucketIterator defines an iterator that batches examples of similar lengths together.
#
# Minimizes amount of padding needed while producing freshly shuffled batches for each new epoch.
#
# batch.QUESTIONS - [ (128) , (128), .. 23 times]

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# TypeError: '<' not supported between instances of 'Example' and 'Example'
# This happens because the dataset iterator from torchtext tries to sort the dataset, which implies comparing two elements. 
# have to provide a sorting function to the constructor of the BucketIterator
BATCH_SIZE = 128

train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
    sort=False,
    batch_size = BATCH_SIZE, 
    device = device)

# %%
batch = next(iter(train_iterator))

# %%
print(batch)
# Out:
# [torchtext.data.batch.Batch of size 128]
# 	[.question]:[torch.cuda.LongTensor of size 19x128 (GPU 0)]
# 	[.answer1]:[torch.cuda.LongTensor of size 22x128 (GPU 0)]

# %%
# Batch contains question and answer1. Can be accessed as batch.question (tensor) and batch.answer1 (tensor)
# batch.question groups the first element of all sequences in batch of 128, then groups second element of sequence in batch 128.
print(type(batch))
print(batch)
print('Data type of batch.question', type(batch.question))
print("Length of a source sequence", len(batch.question))
print("Length of source at first index. (2 is for <sos>)", len(batch.question[0]))
print("Length of source at last index. (6 - what , 8- does )", len(batch.question[-1]))
print("Values at source first index", batch.question[0])
print(batch.answer1[1])
# Out:
# <class 'torchtext.data.batch.Batch'>
#
# [torchtext.data.batch.Batch of size 128]
# 	[.question]:[torch.cuda.LongTensor of size 19x128 (GPU 0)]
# 	[.answer1]:[torch.cuda.LongTensor of size 22x128 (GPU 0)]
# Data type of batch.question <class 'torch.Tensor'>
# Length of a source sequence 19
# Length of source at first index. (2 is for <sos>) 128
# Length of source at last index. (6 - what , 8- does ) 128
# Values at source first index tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2], device='cuda:0')
# tensor([  341,     6,  1107,     8,    24,     6,     5,  1974,  2435,  5031,
#            14,   653,    32,  2999, 10328,   433,  2621,    20,    20,  1263,
#          6598,   139,    24,     0,     8,  5895,     8,   835,   689,    16,
#             6,   973,    13,  8545,     7,  1580,   206,     7,     6,  1175,
#             8,    17,    17,     6,     0,    25,    28,    87,    17,     8,
#          2973,     6,    20,   167,  2987,   611,  1299,   307,  6913,     7,
#          4028,     0,     7,    46,  3936,     0,  2429,     6,    19,  1359,
#            51,  1749,    20,     7,     7,     0,     6,   216,  1523,     5,
#           180,     5,     6,   108,   660,  1695,  3545,  9999,    28,  2360,
#          4750,    14,     8,     0,     6,  6883,    65,  1672,     5,    23,
#            28,    13,    16,   687,     0,  6110,    28,     8,    27,  6409,
#           397,  1563,   162,     5,   243,     6,    14,  4454,     8,     0,
#            24,   172,     8,  1028,     5,   683,     5,    26],
#        device='cuda:0')

# %% [markdown]
# ### Building the Seq2Seq Model
#
# #### Encoder
#
# First, we'll build the encoder. Similar to the previous model, we only use a single layer GRU, however we now use a *bidirectional RNN*. With a bidirectional RNN, we have two RNNs in each layer. A *forward RNN* going over the embedded sentence from left to right (shown below in green), and a *backward RNN* going over the embedded sentence from right to left (teal). All we need to do in code is set `bidirectional = True` and then pass the embedded sentence to the RNN as before.
#
# ![](https://github.com/bentrevett/pytorch-seq2seq/blob/master/assets/seq2seq8.png?raw=1)
#
# We now have:
#
# $$\begin{align*}
# h_t^\rightarrow &= \text{EncoderGRU}^\rightarrow(e(x_t^\rightarrow),h_{t-1}^\rightarrow)\\
# h_t^\leftarrow &= \text{EncoderGRU}^\leftarrow(e(x_t^\leftarrow),h_{t-1}^\leftarrow)
# \end{align*}$$
#
# Where $x_0^\rightarrow = \text{<sos>}, x_1^\rightarrow = \text{guten}$ and $x_0^\leftarrow = \text{<eos>}, x_1^\leftarrow = \text{morgen}$.
#
# As before, we only pass an input (`embedded`) to the RNN, which tells PyTorch to initialize both the forward and backward initial hidden states ($h_0^\rightarrow$ and $h_0^\leftarrow$, respectively) to a tensor of all zeros. We'll also get two context vectors, one from the forward RNN after it has seen the final word in the sentence, $z^\rightarrow=h_T^\rightarrow$, and one from the backward RNN after it has seen the first word in the sentence, $z^\leftarrow=h_T^\leftarrow$.
#
# The RNN returns `outputs` and `hidden`.
#
# `outputs` is of size **[src len, batch size, hid dim * num directions]** where the first `hid_dim` elements in the third axis are the hidden states from the top layer forward RNN, and the last `hid_dim` elements are hidden states from the top layer backward RNN. We can think of the third axis as being the forward and backward hidden states concatenated together other, i.e. $h_1 = [h_1^\rightarrow; h_{T}^\leftarrow]$, $h_2 = [h_2^\rightarrow; h_{T-1}^\leftarrow]$ and we can denote all encoder hidden states (forward and backwards concatenated together) as $H=\{ h_1, h_2, ..., h_T\}$.
#
# `hidden` is of size **[n layers * num directions, batch size, hid dim]**, where **[-2, :, :]** gives the top layer forward RNN hidden state after the final time-step (i.e. after it has seen the last word in the sentence) and **[-1, :, :]** gives the top layer backward RNN hidden state after the final time-step (i.e. after it has seen the first word in the sentence).
#
# As the decoder is not bidirectional, it only needs a single context vector, $z$, to use as its initial hidden state, $s_0$, and we currently have two, a forward and a backward one ($z^\rightarrow=h_T^\rightarrow$ and $z^\leftarrow=h_T^\leftarrow$, respectively). We solve this by concatenating the two context vectors together, passing them through a linear layer, $g$, and applying the $\tanh$ activation function.
#
# $$z=\tanh(g(h_T^\rightarrow, h_T^\leftarrow)) = \tanh(g(z^\rightarrow, z^\leftarrow)) = s_0$$
#
# **Note**: this is actually a deviation from the paper. Instead, they feed only the first backward RNN hidden state through a linear layer to get the context vector/decoder initial hidden state. This doesn't seem to make sense to me, so we have changed it.
#
# As we want our model to look back over the whole of the source sentence we return `outputs`, the stacked forward and backward hidden states for every token in the source sentence. We also return `hidden`, which acts as our initial hidden state in the decoder.

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout):
        super().__init__()

        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, enc_hid_dim, bidirectional = True)
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        #src = [src len, batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src len, batch size, emb dim]
        
        outputs, hidden = self.rnn(embedded)
                
        #outputs = [src len, batch size, hid dim * num directions]
        #hidden = [n layers * num directions, batch size, hid dim]
        
        #hidden is stacked [forward_1, backward_1, forward_2, backward_2, ...]
        #outputs are always from the last layer
        
        #hidden [-2, :, : ] is the last of the forwards RNN 
        #hidden [-1, :, : ] is the last of the backwards RNN
        
        #initial decoder hidden is final hidden state of the forwards and backwards 
        #  encoder RNNs fed through a linear layer
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        
        #outputs = [src len, batch size, enc hid dim * 2]
        #hidden = [batch size, dec hid dim]
        
        return outputs, hidden

# %% [markdown]
# ### Attention
#
# Next up is the attention layer. This will take in the previous hidden state of the decoder, $s_{t-1}$, and all of the stacked forward and backward hidden states from the encoder, $H$. The layer will output an attention vector, $a_t$, that is the length of the source sentence, each element is between 0 and 1 and the entire vector sums to 1.
#
# Intuitively, this layer takes what we have decoded so far, $s_{t-1}$, and all of what we have encoded, $H$, to produce a vector, $a_t$, that represents which words in the source sentence we should pay the most attention to in order to correctly predict the next word to decode, $\hat{y}_{t+1}$.
#
# First, we calculate the *energy* between the previous decoder hidden state and the encoder hidden states. As our encoder hidden states are a sequence of $T$ tensors, and our previous decoder hidden state is a single tensor, the first thing we do is `repeat` the previous decoder hidden state $T$ times. We then calculate the energy, $E_t$, between them by concatenating them together and passing them through a linear layer (`attn`) and a $\tanh$ activation function.
#
# $$E_t = \tanh(\text{attn}(s_{t-1}, H))$$
#
# This can be thought of as calculating how well each encoder hidden state "matches" the previous decoder hidden state.
#
# We currently have a **[dec hid dim, src len]** tensor for each example in the batch. We want this to be **[src len]** for each example in the batch as the attention should be over the length of the source sentence. This is achieved by multiplying the `energy` by a **[1, dec hid dim]** tensor, $v$.
#
# $$\hat{a}_t = v E_t$$
#
# We can think of $v$ as the weights for a weighted sum of the energy across all encoder hidden states. These weights tell us how much we should attend to each token in the source sequence. The parameters of $v$ are initialized randomly, but learned with the rest of the model via backpropagation. Note how $v$ is not dependent on time, and the same $v$ is used for each time-step of the decoding. We implement $v$ as a linear layer without a bias.
#
# Finally, we ensure the attention vector fits the constraints of having all elements between 0 and 1 and the vector summing to 1 by passing it through a $\text{softmax}$ layer.
#
# $$a_t = \text{softmax}(\hat{a_t})$$
#
# This gives us the attention over the source sentence!
#
# Graphically, this looks something like below. This is for calculating the very first attention vector, where $s_{t-1} = s_0 = z$. The green/teal blocks represent the hidden states from both the forward and backward RNNs, and the attention computation is all done within the pink block.
#
# ![](https://github.com/bentrevett/pytorch-seq2seq/blob/master/assets/seq2seq9.png?raw=1)

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        
        self.attn = nn.Linear((enc_hid_dim * 2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias = False)
        
    def forward(self, hidden, encoder_outputs):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #repeat decoder hidden state src_len times
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src len, dec hid dim]

        attention = self.v(energy).squeeze(2)
        
        #attention= [batch size, src len]
        
        return F.softmax(attention, dim=1)

# %% [markdown]
# ### Decoder
#
# Next up is the decoder.
#
# The decoder contains the attention layer, `attention`, which takes the previous hidden state, $s_{t-1}$, all of the encoder hidden states, $H$, and returns the attention vector, $a_t$.
#
# We then use this attention vector to create a weighted source vector, $w_t$, denoted by `weighted`, which is a weighted sum of the encoder hidden states, $H$, using $a_t$ as the weights.
#
# $$w_t = a_t H$$
#
# The embedded input word, $d(y_t)$, the weighted source vector, $w_t$, and the previous decoder hidden state, $s_{t-1}$, are then all passed into the decoder RNN, with $d(y_t)$ and $w_t$ being concatenated together.
#
# $$s_t = \text{DecoderGRU}(d(y_t), w_t, s_{t-1})$$
#
# We then pass $d(y_t)$, $w_t$ and $s_t$ through the linear layer, $f$, to make a prediction of the next word in the target sentence, $\hat{y}_{t+1}$. This is done by concatenating them all together.
#
# $$\hat{y}_{t+1} = f(d(y_t), w_t, s_t)$$
#
# The image below shows decoding the first word in an example translation.
#
# ![](https://github.com/bentrevett/pytorch-seq2seq/blob/master/assets/seq2seq10.png?raw=1)
#
# The green/teal blocks show the forward/backward encoder RNNs which output $H$, the red block shows the context vector, $z = h_T = \tanh(g(h^\rightarrow_T,h^\leftarrow_T)) = \tanh(g(z^\rightarrow, z^\leftarrow)) = s_0$, the blue block shows the decoder RNN which outputs $s_t$, the purple block shows the linear layer, $f$, which outputs $\hat{y}_{t+1}$ and the orange block shows the calculation of the weighted sum over $H$ by $a_t$ and outputs $w_t$. Not shown is the calculation of $a_t$.

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention):
        super().__init__()

        self.output_dim = output_dim
        self.attention = attention
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        
        self.fc_out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, encoder_outputs):
             
        #input = [batch size]
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
        
        a = self.attention(hidden, encoder_outputs)
                
        #a = [batch size, src len]
        
        a = a.unsqueeze(1)
        
        #a = [batch size, 1, src len]
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        
        weighted = torch.bmm(a, encoder_outputs)
        
        #weighted = [batch size, 1, enc hid dim * 2]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim * 2]
        
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        
        #rnn_input = [1, batch size, (enc hid dim * 2) + emb dim]
            
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))
        
        #output = [seq len, batch size, dec hid dim * n directions]
        #hidden = [n layers * n directions, batch size, dec hid dim]
        
        #seq len, n layers and n directions will always be 1 in this decoder, therefore:
        #output = [1, batch size, dec hid dim]
        #hidden = [1, batch size, dec hid dim]
        #this also means that output == hidden
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden.squeeze(0)

# %% [markdown]
# ### Seq2Seq
#
# This is the first model where we don't have to have the encoder RNN and decoder RNN have the same hidden dimensions, however the encoder has to be bidirectional. This requirement can be removed by changing all occurences of `enc_dim * 2` to `enc_dim * 2 if encoder_is_bidirectional else enc_dim`.
#
# This seq2seq encapsulator is similar to the last two. The only difference is that the `encoder` returns both the final hidden state (which is the final hidden state from both the forward and backward encoder RNNs passed through a linear layer) to be used as the initial hidden state for the decoder, as well as every hidden state (which are the forward and backward hidden states stacked on top of each other). We also need to ensure that `hidden` and `encoder_outputs` are passed to the decoder.
#
# Briefly going over all of the steps:
# - the `outputs` tensor is created to hold all predictions, $\hat{Y}$
# - the source sequence, $X$, is fed into the encoder to receive $z$ and $H$
# - the initial decoder hidden state is set to be the `context` vector, $s_0 = z = h_T$
# - we use a batch of `<sos>` tokens as the first `input`, $y_1$
# - we then decode within a loop:
#   - inserting the input token $y_t$, previous hidden state, $s_{t-1}$, and all encoder outputs, $H$, into the decoder
#   - receiving a prediction, $\hat{y}_{t+1}$, and a new hidden state, $s_t$
#   - we then decide if we are going to teacher force or not, setting the next input as appropriate

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
        
    def forward(self, src, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use teacher forcing 75% of the time
        
        batch_size = src.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, hidden = self.encoder(src)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden state and all encoder hidden states
            #receive output tensor (predictions) and new hidden state
            output, hidden = self.decoder(input, hidden, encoder_outputs)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1

        return outputs

# %% [markdown]
# ## Training the Seq2Seq Model
#
# The rest of this session is very similar to the previous one.
#
# We initialise our parameters, encoder, decoder and seq2seq model (placing it on the GPU if we have one).

# %%
INPUT_DIM = len(QUESTIONS.vocab)
OUTPUT_DIM = len(ANSWERS.vocab)
ENC_EMB_DIM = 256
DEC_EMB_DIM = 256
ENC_HID_DIM = 512
DEC_HID_DIM = 512
ENC_DROPOUT = 0.5
DEC_DROPOUT = 0.5

attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, DEC_DROPOUT, attn)

model = Seq2Seq(enc, dec, device).to(device)

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)
            
model.apply(init_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(11000, 256)
#     (rnn): GRU(256, 512, bidirectional=True)
#     (fc): Linear(in_features=1024, out_features=512, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (decoder): Decoder(
#     (attention): Attention(
#       (attn): Linear(in_features=1536, out_features=512, bias=True)
#       (v): Linear(in_features=512, out_features=1, bias=False)
#     )
#     (embedding): Embedding(10651, 256)
#     (rnn): GRU(1280, 512)
#     (fc_out): Linear(in_features=1792, out_features=10651, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 31,073,179 trainable parameters

# %%
optimizer = optim.Adam(model.parameters())

# %%
TRG_PAD_IDX = ANSWERS.vocab.stoi[ANSWERS.pad_token]

criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.question
        trg = batch.answer1
        
        optimizer.zero_grad()
        
        output = model(src, trg)
        
        #trg = [trg len, batch size]
        #output = [trg len, batch size, output dim]
        
        output_dim = output.shape[-1]
        
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.question
            trg = batch.answer1

            output = model(src, trg, 0) #turn off teacher forcing

            #trg = [trg len, batch size]
            #output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]
            
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            #trg = [(trg len - 1) * batch size]
            #output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
train_loss_all = []
val_loss_all = []

# %%
N_EPOCHS = 10
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)

    train_loss_all.append(train_loss)
    val_loss_all.append(valid_loss)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut3-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 01 | Time: 1m 45s
# 	Train Loss: 5.982 | Train PPL: 396.285
# 	 Val. Loss: 5.459 |  Val. PPL: 234.815
# Epoch: 02 | Time: 1m 44s
# 	Train Loss: 5.390 | Train PPL: 219.120
# 	 Val. Loss: 5.341 |  Val. PPL: 208.810
# Epoch: 03 | Time: 1m 45s
# 	Train Loss: 5.135 | Train PPL: 169.883
# 	 Val. Loss: 5.273 |  Val. PPL: 194.945
# Epoch: 04 | Time: 1m 44s
# 	Train Loss: 4.877 | Train PPL: 131.230
# 	 Val. Loss: 5.289 |  Val. PPL: 198.131
# Epoch: 05 | Time: 1m 44s
# 	Train Loss: 4.602 | Train PPL:  99.721
# 	 Val. Loss: 5.310 |  Val. PPL: 202.346
# Epoch: 06 | Time: 1m 44s
# 	Train Loss: 4.289 | Train PPL:  72.917
# 	 Val. Loss: 5.418 |  Val. PPL: 225.403
# Epoch: 07 | Time: 1m 45s
# 	Train Loss: 3.919 | Train PPL:  50.370
# 	 Val. Loss: 5.564 |  Val. PPL: 260.792
# Epoch: 08 | Time: 1m 44s
# 	Train Loss: 3.453 | Train PPL:  31.591
# 	 Val. Loss: 5.746 |  Val. PPL: 313.006
# Epoch: 09 | Time: 1m 44s
# 	Train Loss: 2.982 | Train PPL:  19.737
# 	 Val. Loss: 5.873 |  Val. PPL: 355.322
# Epoch: 10 | Time: 1m 45s
# 	Train Loss: 2.618 | Train PPL:  13.711
# 	 Val. Loss: 6.083 |  Val. PPL: 438.546

# %%
model.load_state_dict(torch.load('tut3-model.pt'))

test_loss = evaluate(model, test_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 5.265 | Test PPL: 193.382 |

# %% [markdown]
# Train, val loss curve

# %%
import matplotlib.pyplot as plt
def train_test_metrics_graph(train_loss_all, val_loss_all):

    plt.plot(train_loss_all, label="Train Loss")
    plt.plot(val_loss_all, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Loss vs Epoch curve")

# %%
train_test_metrics_graph(train_loss_all, val_loss_all)
